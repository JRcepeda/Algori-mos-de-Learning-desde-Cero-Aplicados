# %%
import numpy as np
import pandas as pd
from scipy import stats 
import typing
import tqdm
import random
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
datos=pd.read_csv('Datos\CarPrice_Assignment.csv',index_col=0)
datos.head()
# Out:
#         symboling                   CarName fueltype aspiration doornumber  \
# car_ID
# 1               3        alfa-romero giulia      gas        std        two
# 2               3       alfa-romero stelvio      gas        std        two
# 3               1  alfa-romero Quadrifoglio      gas        std        two
# 4               2               audi 100 ls      gas        std       four
# 5               2                audi 100ls      gas        std       four
#
#             carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# car_ID                                                               ...
# 1       convertible        rwd          front       88.6      168.8  ...
# 2       convertible        rwd          front       88.6      168.8  ...
# 3         hatchback        rwd          front       94.5      171.2  ...
# 4             sedan        fwd          front       99.8      176.6  ...
# 5             sedan        4wd          front       99.4      176.6  ...
#
#         enginesize  fuelsystem  boreratio stroke compressionratio  horsepower  \
# car_ID
# 1              130        mpfi       3.47   2.68              9.0         111
# 2              130        mpfi       3.47   2.68              9.0         111
# 3              152        mpfi       2.68   3.47              9.0         154
# 4              109        mpfi       3.19   3.40             10.0         102
# 5              136        mpfi       3.19   3.40              8.0         115
#
#        peakrpm  citympg  highwaympg    price
# car_ID
# 1         5000       21          27  13495.0
# 2         5000       21          27  16500.0
# 3         5000       19          26  16500.0
# 4         5500       24          30  13950.0
# 5         5500       18          22  17450.0
#
# [5 rows x 25 columns]

# %% [markdown]
# En este conjunto de datos se presentan las caracteristicas de distintos vehículos con su respectivo precio, el cual es de interés pronosticar. En este caso empleremos una regresión lineal multiple programada desde cero.

# %%
datos.isna().sum()
# Out:
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
datos.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_1e066_row0_col0, #T_1e066_row1_col1, #T_1e066_row2_col2, #T_1e066_row3_col3, #T_1e066_row4_col4, #T_1e066_row5_col5, #T_1e066_row6_col6, #T_1e066_row7_col7, #T_1e066_row8_col8, #T_1e066_row9_col9, #T_1e066_row10_col10, #T_1e066_row11_col11, #T_1e066_row12_col12, #T_1e066_row13_col13, #T_1e066_row14_col14 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_1e066_row0_col1, #T_1e066_row7_col8 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_1e066_row0_col2, #T_1e066_row5_col0 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_1e066_row0_col3 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_1e066_row0_col4, #T_1e066_row4_col0, #T_1e066_row5_col13, #T_1e066_row9_col11, #T_1e066_row10_col12, #T_1e066_row11_col8, #T_1e066_row11_col9, #T_1e066_row12_col7, #T_1e066_row12_col10, #T_1e066_row13_col1, #T_1e066_row13_col2, #T_1e066_row13_col3, #T_1e066_row13_col5, #T_1e066_row13_col6, #T_1e066_row13_col7, #T_1e066_row13_col14 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_1e066_row0_col5, #T_1e066_row12_col4 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_1e066_row0_col6 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_1e066_row0_col7 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_1e066_row0_col8, #T_1e066_row14_col13 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_1e066_row0_col9 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_1e066_row0_col10, #T_1e066_row4_col14 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_1e066_row0_col11 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_1e066_row0_col12 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_1e066_row0_col13, #T_1e066_row7_col4 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_1e066_row0_col14 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_1e066_row1_col0, #T_1e066_row12_col14 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_1e066_row1_col2, #T_1e066_row3_col5, #T_1e066_row5_col2, #T_1e066_row6_col14 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_1e066_row1_col3, #T_1e066_row1_col5 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_1e066_row1_col4, #T_1e066_row4_col1, #T_1e066_row10_col7 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_1e066_row1_col6 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_1e066_row1_col7 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_1e066_row1_col8 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_1e066_row1_col9, #T_1e066_row4_col7 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_1e066_row1_col10 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_1e066_row1_col11, #T_1e066_row2_col13 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_1e066_row1_col12, #T_1e066_row2_col8 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_1e066_row1_col13, #T_1e066_row11_col4 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_1e066_row1_col14, #T_1e066_row2_col7, #T_1e066_row2_col10, #T_1e066_row7_col6 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_1e066_row2_col0, #T_1e066_row5_col11, #T_1e066_row7_col12, #T_1e066_row11_col1 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_1e066_row2_col1, #T_1e066_row5_col3 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_1e066_row2_col3, #T_1e066_row5_col14 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_1e066_row2_col4, #T_1e066_row7_col1 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_1e066_row2_col5 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_1e066_row2_col6 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_1e066_row2_col9, #T_1e066_row11_col13 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_1e066_row2_col11 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_1e066_row2_col12 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_1e066_row2_col14, #T_1e066_row6_col2, #T_1e066_row14_col2 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_1e066_row3_col0 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_1e066_row3_col1 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_1e066_row3_col2, #T_1e066_row14_col5 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_1e066_row3_col4 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_1e066_row3_col6, #T_1e066_row6_col3 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_1e066_row3_col7, #T_1e066_row6_col1 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_1e066_row3_col8, #T_1e066_row9_col0, #T_1e066_row9_col8 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_1e066_row3_col9, #T_1e066_row14_col4 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_1e066_row3_col10 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_1e066_row3_col11 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_1e066_row3_col12 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_1e066_row3_col13, #T_1e066_row6_col13 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_1e066_row3_col14, #T_1e066_row14_col3 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_1e066_row4_col2 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_1e066_row4_col3 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_1e066_row4_col5 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_1e066_row4_col6 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_1e066_row4_col8, #T_1e066_row10_col13, #T_1e066_row12_col6 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_1e066_row4_col9, #T_1e066_row13_col9 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_1e066_row4_col10, #T_1e066_row4_col13 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_1e066_row4_col11 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_1e066_row4_col12 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_1e066_row5_col1 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_1e066_row5_col4 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_1e066_row5_col6 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_1e066_row5_col7 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_1e066_row5_col8 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_1e066_row5_col9 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_1e066_row5_col10, #T_1e066_row10_col5 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_1e066_row5_col12, #T_1e066_row12_col8 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_1e066_row6_col0, #T_1e066_row13_col4 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_1e066_row6_col4, #T_1e066_row10_col0, #T_1e066_row10_col11 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_1e066_row6_col5 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# #T_1e066_row6_col7, #T_1e066_row7_col3, #T_1e066_row7_col14, #T_1e066_row10_col2 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_1e066_row6_col8 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_1e066_row6_col9 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_1e066_row6_col10, #T_1e066_row14_col10 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_1e066_row6_col11 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_1e066_row6_col12 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_1e066_row7_col0, #T_1e066_row13_col11 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_1e066_row7_col2 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_1e066_row7_col5 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_1e066_row7_col9 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_1e066_row7_col10 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_1e066_row7_col11 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_1e066_row7_col13 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_1e066_row8_col0 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_1e066_row8_col1 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_1e066_row8_col2, #T_1e066_row8_col10 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_1e066_row8_col3, #T_1e066_row9_col1, #T_1e066_row9_col3 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_1e066_row8_col4 {
#   background-color: #a3c2fe;
#   color: #

# %% [markdown]
# # Preprocesamiento

# %%
escalador=MinMaxScaler()

# %%
y=np.array(datos['price'])
x=datos.drop(['price'],axis=1)
x=x.loc[:,['symboling','wheelbase','carlength','carwidth','carheight',	'curbweight','enginesize','boreratio','horsepower','peakrpm','citympg','highwaympg']]
X=escalador.fit_transform(x)
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %% [markdown]
# # Creación del modelo desde cero

# %%
class Linear_Regression:
    coef: float
    
    #para estimar los coeficientes de acuerdo a la función de perdida
    def gradient(self,x,y,coef):
        err=y-np.dot(x,coef)#error de pronostico (y-y^)
        return -2*err*x #mutiplica el 2*error por cada vector de x 
    
    def det_coef(self,coef,dxi_loss,learning_rate):
        coef-=dxi_loss[0]*np.array([learning_rate])
        return coef
    
    #para entrenar el modelo
    def fit(self,x_train,y_train,learning_rate=0.001,epochs=1000,batch_size=27,random_s=None):
        np.random.seed(random_s)
        self.x_train=x_train
        self.y_train=y_train
        self.coef=np.random.randn(self.x_train.shape[1])#np.random.randn(x_train.shape[1])
        
        for t in tqdm.trange(epochs):
            for i in range(0,len(self.x_train),batch_size):
                b_xt=self.x_train[i:i+batch_size]
                b_yt=self.y_train[i:i+batch_size]
                    
                #para calcular el gradiente, dependiendo del tamaño del batch se calcula el promedio de la derivada parcial para el movimiento de cada beta
                dxi_loss=np.mean([[self.gradient(xi,yi,self.coef)]for xi,yi in zip(b_xt,b_yt)],axis=0)#np.mean(,axis=0)
                #print(dxi_loss.shape)
                #para estimar los coeficientes de acuerdo a los resultados del gradiente
                self.coef=self.det_coef(self.coef,dxi_loss,learning_rate)
                
    #permite obtener estadisticas de la signifiancia individual de cada coeficiente
    def standard_error(self,name_var=None):
        #suma de cuadrados de los residuos
        sse=sum((self.y_train-self.predict(x_train))**2)
        #varianza residual con dos grados de libertad
        sigma2=sse/(y_train.shape[0]-2)
        #coovarinza de los coeficientes
        try:
            inversa=np.linalg.inv(np.dot(self.x_train.T,self.x_train))
        except:
            pass
        cov=(sigma2*inversa)
        #raiz de la varianza de los betas
        StdErrorB=np.sqrt(np.diag(cov))
        #error estaandar
        statistic=self.coef/StdErrorB
        #se prueba los erroes en una distribución t con 2 grados de libertad
        p_val=(1-(stats.t(df=2).cdf(statistic)))
        print('\t***********************************************')
        print('\t Significancia individual de los coeficientes  ')
        print('\t-----------------------------------------------')
        if name_var==None:
            st_cof=pd.DataFrame({'Coeficientes':self.coef,'P Value':p_val,'Estadístico':statistic},index=name_var)
            print(f'{st_cof}')

        else:            
           st_cof=pd.DataFrame({'Coeficientes':self.coef,'P Value':p_val,'Estadístico':statistic},index=name_var)
           print(f'{st_cof}')
           
    #pronostica los resultados de acuerdo a los datos de entrenamiento
    def predict(self,x_test):
        return np.dot(x_test,self.coef)

# %% [markdown]
# # Creación del objeto y entrenamiento del modelo

# %%
modelo=Linear_Regression()

# %%
modelo.fit(x_train,y_train,learning_rate=.01,random_s=123)
# Out:
#   8%|▊         | 85/1000 [00:01<00:11, 81.61it/s]
# 100%|██████████| 1000/1000 [00:11<00:00, 89.48it/s]

# %% [markdown]
# # Evaluación del modelo y estadísticas de los coeficientes

# %%
resultados=modelo.predict(x_test)

# %%
modelo.standard_error(x.columns.to_list())
# Out:
# 	***********************************************
# 	 Significancia individual de los coeficientes
# 	-----------------------------------------------
#             Coeficientes   P Value  Estadístico
# symboling     545.152358  0.370072     0.380566
# wheelbase    1071.557374  0.423562     0.218772
# carlength   -2185.103194  0.654647    -0.459961
# carwidth     6480.730152  0.109635     1.766966
# carheight    2132.962912  0.207738     1.018816
# curbweight  10796.914284  0.083422     2.130515
# enginesize  16119.320620  0.036572     3.491507
# boreratio   -1020.731609  0.679972    -0.545608
# horsepower  11281.527770  0.075268     2.276759
# peakrpm       757.809993  0.357979     0.418953
# citympg     -1148.007342  0.550070    -0.142334
# highwaympg  -1056.452946  0.547929    -0.136191

# %%
resultados=modelo.predict(x_test)

# %%
r2_score(y_test,resultados)
# Out:
# 0.8966793232148225

# %%
plt.scatter(x=range(0,y_test.shape[0]),y=y_test)
plt.plot(resultados,label='pronostico')
plt.title('Resultados del modelo')
plt.ylabel('$ Precio vehículo')
plt.legend()
plt.show()
